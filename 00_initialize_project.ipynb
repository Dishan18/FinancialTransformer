# %%
import os
import pandas as pd

os.makedirs("experiments", exist_ok=True)
os.makedirs("models", exist_ok=True)

# %%
import os
import pandas as pd

os.makedirs("experiments", exist_ok=True)
os.makedirs("models", exist_ok=True)

# %%
trading_results = pd.DataFrame(columns=[
    "Model",
    "Direction Accuracy",
    "Hit Rate",
    "Sharpe",
    "Strategy Return",
    "Max Drawdown"
])

trading_results.to_csv(
    "experiments/trading_results.csv",
    index=False
)

# %%
experiment_log = pd.DataFrame(columns=[
    "Experiment",
    "Model",
    "Parameters",
    "Train Time (s)",
    "Epochs",
    "MAE",
    "RMSE",
    "R2",
    "Direction Accuracy",
    "Hit Rate",
    "Sharpe",
    "Strategy Return",
    "Max Drawdown",
    "Notes"
])

experiment_log.to_csv(
    "experiments/experiment_log.csv",
    index=False
)
